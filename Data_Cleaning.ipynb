# %%
#Loading the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#I will be using the below code in order to see the complete data. 
#pd.set_option('display.max_rows',None)

# %%
data = pd.read_csv('agriculture.csv')
data.shape
# Out:
# (345407, 10)

# %%
data.head()
# Out:
#                          State                  District      Crop     Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2001-02
# 1  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2002-03
# 2  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2003-04
# 3  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2001-02
# 4  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2002-03
#
#        Season    Area Area Units  Production Production Units     Yield
# 0      Kharif  1254.0    Hectare      2061.0           Tonnes  1.643541
# 1  Whole Year  1258.0    Hectare      2083.0           Tonnes  1.655803
# 2  Whole Year  1261.0    Hectare      1525.0           Tonnes  1.209358
# 3      Kharif  3100.0    Hectare      5239.0           Tonnes  1.690000
# 4  Whole Year  3105.0    Hectare      5267.0           Tonnes  1.696296

# %%
#Checking whether the data contains null values or not

data.isna().sum()
# Out:
# State                  0
# District               0
# Crop                  32
# Year                   0
# Season                 1
# Area                  33
# Area Units             0
# Production          4993
# Production Units       0
# Yield                 33
# dtype: int64

# %% [markdown]
# This dataset containes null values.
#
# Compared to the number of entries, the number of rows containing null values is very small. So I will be dropping the entries containing null values

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 340414 entries, 0 to 345374
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   State             340414 non-null  object
#  1   District          340414 non-null  object
#  2   Crop              340414 non-null  object
#  3   Year              340414 non-null  object
#  4   Season            340414 non-null  object
#  5   Area              340414 non-null  float64
#  6   Area Units        340414 non-null  object
#  7   Production        340414 non-null  float64
#  8   Production Units  340414 non-null  object
#  9   Yield             340414 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 28.6+ MB

# %%
data['State'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Delhi',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Telangana', 'Laddakh'], dtype=object)

# %% [markdown]
# So the data contains information about all the Sates and Union Territories of India.
#
# Let's look at the types of Crops present in this dataset.

# %%
print("Total types of Crops present in this data : ", len(data['Crop'].unique()))
data['Crop'].unique()
# Out:
# Total types of Crops present in this data :  56
# array(['Arecanut', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut',
#        'Dry chillies', 'Ginger', 'Other Kharif pulses', 'other oilseeds',
#        'Rice', 'Sugarcane', 'Sweet potato', 'Arhar/Tur', 'Bajra',
#        'Castor seed', 'Coriander', 'Cotton(lint)', 'Gram', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Linseed', 'Maize', 'Mesta',
#        'Moong(Green Gram)', 'Niger seed', 'Onion', 'Other Rabi pulses',
#        'Potato', 'Ragi', 'Rapeseed &Mustard', 'Safflower', 'Sesamum',
#        'Small millets', 'Soyabean', 'Sunflower', 'Tapioca', 'Tobacco',
#        'Turmeric', 'Urad', 'Wheat', 'Oilseeds total', 'Jute', 'Masoor',
#        'Peas & beans (Pulses)', 'Barley', 'Garlic', 'Khesari', 'Sannhamp',
#        'Guar seed', 'Moth', 'Cardamom', 'Other Cereals', 'Cowpea(Lobia)',
#        'Dry Ginger', 'Other Summer Pulses'], dtype=object)

# %% [markdown]
# To verify whether the data is appropriate I can't check the entire dataset, but since I'm from Telangana I'll look at the the District names of both Telangana and Andhra Pradesh and verify. If I find something wrong I'll then change the data accordingly.
#
#
#
# Here I'm checking the data of Telangana State.

# %%
data1 = data[data['State']=='Telangana']
data1
# Out:
#             State                District       Crop     Year  Season  \
# 214087  Telangana                ADILABAD  Arhar/Tur  2013-14  Kharif
# 214088  Telangana                ADILABAD  Arhar/Tur  2013-14    Rabi
# 214089  Telangana                ADILABAD  Arhar/Tur  2014-15  Kharif
# 214090  Telangana                ADILABAD  Arhar/Tur  2014-15    Rabi
# 214091  Telangana                ADILABAD  Arhar/Tur  2015-16  Kharif
# ...           ...                     ...        ...      ...     ...
# 294278  Telangana                   DAMAN       Rice  2019-20  Kharif
# 294279  Telangana  DADRA AND NAGAR HAVELI    Sesamum  2019-20  Kharif
# 294280  Telangana  DADRA AND NAGAR HAVELI  Sugarcane  2019-20    Rabi
# 294281  Telangana  DADRA AND NAGAR HAVELI       Urad  2019-20  Kharif
# 294282  Telangana  DADRA AND NAGAR HAVELI      Wheat  2019-20    Rabi
#
#            Area Area Units  Production Production Units      Yield
# ...

# %%
data1['District'].unique()
# Out:
# array(['ADILABAD', 'KARIMNAGAR', 'KHAMMAM', 'MAHBUBNAGAR', 'MEDAK',
#        'NALGONDA', 'NIZAMABAD', 'RANGAREDDI', 'WARANGAL', 'BHADRADRI',
#        'JAGITIAL', 'JANGOAN', 'JAYASHANKAR', 'JOGULAMBA', 'KAMAREDDY',
#        'KOMARAM BHEEM ASIFABAD', 'MAHABUBABAD', 'MANCHERIAL', 'MEDCHAL',
#        'MULUGU', 'NAGARKURNOOL', 'NARAYANAPET', 'NIRMAL', 'PEDDAPALLI',
#        'RAJANNA', 'SANGAREDDY', 'SIDDIPET', 'SURYAPET', 'VIKARABAD',
#        'WANAPARTHY', 'WARANGAL URBAN', 'YADADRI', 'HANUMAKONDA',
#        'MEDCHAL MALKAJGIRI', 'DADRA AND NAGAR HAVELI', 'DIU', 'DAMAN'],
#       dtype=object)

# %% [markdown]
# As seen above here districts like Dadra and Nagar Haveli,Daman,etc are also included in the data of Telangana State.
#
# Now let us look at the data of Andhra Pradesh.

# %%
data2 = data[data['State']=='Andhra Pradesh'] 
data2['District'].unique()
# Out:
# array(['ANANTAPUR', 'EAST GODAVARI', 'KRISHNA', 'VIZIANAGARAM',
#        'WEST GODAVARI', 'ADILABAD', 'CHITTOOR', 'GUNTUR', 'KADAPA',
#        'KARIMNAGAR', 'KHAMMAM', 'KURNOOL', 'MAHBUBNAGAR', 'MEDAK',
#        'NALGONDA', 'NIZAMABAD', 'PRAKASAM', 'RANGAREDDI', 'SPSR NELLORE',
#        'SRIKAKULAM', 'VISAKHAPATANAM', 'WARANGAL', 'HYDERABAD'],
#       dtype=object)

# %% [markdown]
# From the AP's dataset I found no anamolies in the data.
#
# So from the above observations I will check the data related to Dadra and Nagar Haveli, Daman, Diu and clean the data.

# %%
#Extracting the data where District is from ['DADRA AND NAGAR HAVELI', 'DIU', 'DAMAN']

# %%
# cleaning3 = data[data['District']=='DIU']
# cleaning3

# %%
data_for_cleaning = pd.DataFrame(columns=['State','District','Crop','Year','Season','Area','Area Units','Production','Production Units','Yield'],index=None)
data_for_cleaning
# Out:
# Empty DataFrame
# Columns: [State, District, Crop, Year, Season, Area, Area Units, Production, Production Units, Yield]
# Index: []

# %%
check = ['DADRA AND NAGAR HAVELI', 'DIU', 'DAMAN']

# %%
for i in check:
    new_rows = data1[data1['District']==i]
#     print(type(new_rows))
    frames = [data_for_cleaning,new_rows]
    data_for_cleaning = pd.concat(frames)

# %%
#data_for_cleaning.dropna(inplace=True)
data_for_cleaning
# Out:
#             State                District               Crop     Year  Season  \
# 294264  Telangana  DADRA AND NAGAR HAVELI          Arhar/Tur  2019-20  Kharif
# 294265  Telangana  DADRA AND NAGAR HAVELI          Arhar/Tur  2019-20    Rabi
# 294267  Telangana  DADRA AND NAGAR HAVELI      Cowpea(Lobia)  2019-20  Kharif
# 294268  Telangana  DADRA AND NAGAR HAVELI          Groundnut  2019-20  Kharif
# 294269  Telangana  DADRA AND NAGAR HAVELI              Jowar  2019-20  Kharif
# 294270  Telangana  DADRA AND NAGAR HAVELI              Maize  2019-20  Kharif
# 294271  Telangana  DADRA AND NAGAR HAVELI         Niger seed  2019-20  Kharif
# 294272  Telangana  DADRA AND NAGAR HAVELI         Niger seed  2019-20    Rabi
# 294273  Telangana  DADRA AND NAGAR HAVELI  Other Rabi pulses  2019-20    Rabi
# 294274  Telangana  DADRA AND NAGAR HAVELI               Ragi  2019-20  Kharif
# 294275  Telangana  DADRA AND NAGAR HAVELI  Rapeseed &Mustard  2019-20    Rabi
# ...

# %%
#data_for_cleaning.loc[294266,['State']] = ['Daman and Diu']

# %% [markdown]
# So now let's change the data in the actual dataframe

# %%
data.loc[294264:294282,['State']] = ['Dadra and Nagar Haveli']

# %%
data.loc[294278,['State']] = ['Daman and Diu']

# %%
#diu = data[data['State']=='Daman and Diu']
#diu

# %%
# dnh = data[data['State']=='Dadra and Nagar Haveli']
# dnh

# %%
#diu['District'].value_counts()

# %%
# dnh['District'].value_counts()

# %%
# data1 = data[data['State']=='Telangana']
# data1['District'].unique()

# %%
data.to_csv("Cleaned_Data.csv")

# %% [markdown]
# As said above I had cleaned the data and saved the data in the file named "Cleaned_Data.csv"
